# %%
import os
from bs4 import BeautifulSoup as bs
import pandas

farming=[]
biota=[]
boundaries=[]
climatologyMeteorologyAtmosphere=[]
economy=[]
elevation=[]
environment=[]
geoscientificInformation=[]
health=[]
imageryBaseMapsEarthCover=[]
intelligenceMilitary=[]
inlandWaters=[]
location=[]
oceans=[]
planningCadastre=[]
society=[]
structure=[]
transportation=[]
utilitiesCommunication=[]


concordance = {
    "farming":farming,
    "biota":biota,
    "boundaries":boundaries,
    "climatologyMeteorologyAtmosphere":climatologyMeteorologyAtmosphere,
    "economy": economy,
    "elevation": elevation,
    "environment":environment,
    "geoscientificInformation":geoscientificInformation,
    "health":health,
    "imageryBaseMapsEarthCover":imageryBaseMapsEarthCover,
    "intelligenceMilitary":intelligenceMilitary,
    "inlandWaters":inlandWaters,
    "location":location,
    "oceans":oceans,
    "planningCadastre":planningCadastre,
    "society":society,
    "structure":structure,
    "transportation":transportation,
    "utilitiesCommunication":utilitiesCommunication
}

# filenames "fgcd12345.xml" from "1" to "10016" but missing "9985"-"9999"

baseFilePath = "../FGDC_xml/fgdc"
filerangeStart = 1
filerangeEnd = 10016
fileCount = 0

beginMsg = "Beginning with file number {} "
print(beginMsg.format(filerangeStart))

for i in range (filerangeStart, filerangeEnd):
    filename = baseFilePath + str(i) + ".xml"
    if os.path.isfile(filename):
        isoThemes = set()
        
        lcshThemes = set()

        with open (filename, "r", encoding="utf-8") as f:
            themeString = ""
            fgdc = bs(f, "xml")
            keywords = fgdc.find_all("keywords")

            #Search XML for <theme> in each record
            for keyword in keywords:
                themes = keyword.find_all("theme")
                for theme in themes:
                    #isolate the type of theme
                    themeString = theme.find_all()[0].string
                    if(themeString == "ISO 19115 Topic Category"):
                        themekeys = theme.find_all("themekey")
                        for themekey in themekeys:
                            isoThemes.add(themekey.string)
                        #print(filename, isoThemes)
                    elif (themeString == "LCSH"):
                        #print(themeString, "===>")
                        themekeys = theme.find_all("themekey")
                        for themekey in themekeys:
                            lcshThemes.add(themekey.string)

            # After processing each xml file, Add key to concordance if not already present, 
            # (to catch erroneous terms) and append lcsh set
            for isotheme in isoThemes:
                if not(isotheme in concordance):
                    concordance[isotheme] = []
                for lcsh in lcshThemes:
                    concordance[isotheme].append(lcsh)
            fileCount += 1
            if fileCount%250 == 0:
                print("Processed",fileCount, "files...")
    else:
        print(filename, "not found.")

isoLcsh = {}

for k, v in concordance.items():
    if len(v) > 0:
        isoLcsh[k]=list(set(v))

# Create dataframe; creating it with orient='index' (default is the other choice, 'column')
# and then transposing is one trick for handling errors arising from columns of unequal length. 

df = pandas.DataFrame.from_dict(isoLcsh, orient='index')
dft = df.transpose()

endMessage = ("Processed {} files")
print(endMessage.format(fileCount))

#export to csv

csv_path = r"iso_lcsh_themes.csv"

export_csv = dft.to_csv (csv_path, index = None, header=True)
print("Exporting Data Frame results to:", csv_path)

##pp = pprint.PrettyPrinter(indent=4)
##pp.pprint(isoLcsh)
# Out:
# Beginning with file number 1
# Processed 250 files...
# Processed 500 files...
# Processed 750 files...
# ../FGDC_xml/fgdc999.xml not found.
# Processed 1000 files...
# Processed 1250 files...
# Processed 1500 files...
# Processed 1750 files...
# Processed 2000 files...
# Processed 2250 files...
# Processed 2500 files...
# Processed 2750 files...
# Processed 3000 files...
# Processed 3250 files...
# Processed 3500 files...
# Processed 3750 files...
# Processed 4000 files...
# Processed 4250 files...
# Processed 4500 files...
# Processed 4750 files...
# Processed 5000 files...
# Processed 5250 files...
# Processed 5500 files...
# Processed 5750 files...
# Processed 6000 files...
# Processed 6250 files...
# Processed 6500 files...
# Processed 6750 files...
# Processed 7000 files...
# Processed 7250 files...
# Processed 7500 files...
# Processed 7750 files...
# Processed 8000 files...
# Processed 8250 files...
# Processed 8500 files...
# Processed 8750 files...
# Processed 9000 files...
# Processed 9250 files...
# Processed 9500 files...
# Processed 9750 files...
# ../FGDC_xml/fgdc9985.xml not found.
# ../FGDC_xml/fgdc9986.xml not found.
# ../FGDC_xml/fgdc9987.xml not found.
# ../FGDC_xml/fgdc9988.xml not found.
# ../FGDC_xml/fgdc9989.xml not found.
# ../FGDC_xml/fgdc9990.xml not found.
# ../FGDC_xml/fgdc9991.xml not found.
# ../FGDC_xml/fgdc9992.xml not found.
# ../FGDC_xml/fgdc9993.xml not found.
# ../FGDC_xml/fgdc9994.xml not found.
# ../FGDC_xml/fgdc9995.xml not found.
# ../FGDC_xml/fgdc9996.xml not found.
# ../FGDC_xml/fgdc9997.xml not found.
# ../FGDC_xml/fgdc9998.xml not found.
# ../FGDC_xml/fgdc9999.xml not found.
# Processed 9999 files
# Exporting Data Frame results to: iso_lcsh_themes.csv
